# %%
import pandas as pd
from sklearn.impute import SimpleImputer
from numpy import nan
from numpy import isnan
from sklearn.preprocessing import StandardScaler

dataset = pd.read_csv('data/credit-card-holder-data/cc-general.csv')

if dataset['CUST_ID'].is_unique:
    dataset.set_index('CUST_ID', inplace=True)
    print("CUST_ID is unique and is now the index.")
else:
    dataset.drop('CUST_ID', axis=1, inplace=True)
    print("CUST_ID was not unique and has been removed.")

imputer = SimpleImputer(missing_values=nan, strategy='mean')
imputed_dataset = imputer.fit_transform(dataset)
# when imputing data we loose column names, adding them back in.
imputed_dataset = pd.DataFrame(imputed_dataset, columns=dataset.columns)


scaled_imputed_dataset = StandardScaler().fit_transform(imputed_dataset)
print("Scaled Imputed Dataset Shape : ", scaled_imputed_dataset.shape)
# Out:
# CUST_ID is unique and is now the index.
# Scaled Imputed Dataset Shape :  (8950, 17)

# %%
from sklearn.cluster import KMeans
# kmeans-noc-9--init-k-means++--n_init-15--tol-1e-05--algo-elkan
kmeans = KMeans(n_clusters = 3 ,init='k-means++', n_init = 15 ,max_iter=500, tol=0.00001,  random_state= 111, algorithm='elkan')
kmeans.fit(scaled_imputed_dataset)
# Out:
# KMeans(algorithm='elkan', max_iter=500, n_clusters=3, n_init=15,
#        random_state=111, tol=1e-05)

# %%
import matplotlib.pyplot as plt
from itertools import combinations
import numpy as np
import os

columns = imputed_dataset.columns

column_combinations = combinations(columns, 3)

num_combinations = len(list(column_combinations))
run = 0

column_combinations = combinations(columns, 3)

for combo in column_combinations:
    run = 1 + run
    x, y, z = combo
    print('')
    print('------------------------------------------------------------------------------------------------')
    print(f'Run {run}/{num_combinations}  Now running combo : x {x} - y {y} - z {z}')
    print('------------------------------------------------------------------------------------------------')
    print('') 

    
    fig = plt.figure(figsize=(12, 8))
    ax = fig.add_subplot(projection='3d')
    

    scatter = ax.scatter(imputed_dataset[x], imputed_dataset[y], imputed_dataset[z], c=kmeans.labels_, cmap='viridis', s=20)

    ax.set_xlabel(x)
    ax.set_ylabel(y)
    ax.set_zlabel(z)

    unique_labels = np.unique(kmeans.labels_)
    legend_labels = {}

    for label in unique_labels:
        value = f'Cluster {label}'
        legend_labels[label] = value

    legend_handles = []

    for label, legend in legend_labels.items():
        color = plt.cm.viridis(label / max(kmeans.labels_))
        handle = plt.Line2D([0], [0], marker='o', color='w', label=legend, markerfacecolor=color, markersize=10)
        legend_handles.append(handle)

    ax.legend(handles=legend_handles, title="Clusters")


    filename = f"{x}_{y}_{z}.png"
    if not os.path.exists('/tmp/data/3d-data/'):
        os.makedirs('/tmp/data/3d-data/')
    plt.savefig(f'/tmp/data/3d-data/{filename}')
    plt.close()

print("All plots with legends are saved.")
# Out:
# ------------------------------------------------------------------------------------------------
# Run 1/680  Now running combo : x BALANCE - y BALANCE_FREQUENCY - z PURCHASES
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 2/680  Now running combo : x BALANCE - y BALANCE_FREQUENCY - z ONEOFF_PURCHASES
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 3/680  Now running combo : x BALANCE - y BALANCE_FREQUENCY - z INSTALLMENTS_PURCHASES
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 4/680  Now running combo : x BALANCE - y BALANCE_FREQUENCY - z CASH_ADVANCE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 5/680  Now running combo : x BALANCE - y BALANCE_FREQUENCY - z PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 6/680  Now running combo : x BALANCE - y BALANCE_FREQUENCY - z ONEOFF_PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 7/680  Now running combo : x BALANCE - y BALANCE_FREQUENCY - z PURCHASES_INSTALLMENTS_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 8/680  Now running combo : x BALANCE - y BALANCE_FREQUENCY - z CASH_ADVANCE_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 9/680  Now running combo : x BALANCE - y BALANCE_FREQUENCY - z CASH_ADVANCE_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 10/680  Now running combo : x BALANCE - y BALANCE_FREQUENCY - z PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 11/680  Now running combo : x BALANCE - y BALANCE_FREQUENCY - z CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 12/680  Now running combo : x BALANCE - y BALANCE_FREQUENCY - z PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 13/680  Now running combo : x BALANCE - y BALANCE_FREQUENCY - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 14/680  Now running combo : x BALANCE - y BALANCE_FREQUENCY - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 15/680  Now running combo : x BALANCE - y BALANCE_FREQUENCY - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 16/680  Now running combo : x BALANCE - y PURCHASES - z ONEOFF_PURCHASES
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 17/680  Now running combo : x BALANCE - y PURCHASES - z INSTALLMENTS_PURCHASES
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 18/680  Now running combo : x BALANCE - y PURCHASES - z CASH_ADVANCE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 19/680  Now running combo : x BALANCE - y PURCHASES - z PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 20/680  Now running combo : x BALANCE - y PURCHASES - z ONEOFF_PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 21/680  Now running combo : x BALANCE - y PURCHASES - z PURCHASES_INSTALLMENTS_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 22/680  Now running combo : x BALANCE - y PURCHASES - z CASH_ADVANCE_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 23/680  Now running combo : x BALANCE - y PURCHASES - z CASH_ADVANCE_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 24/680  Now running combo : x BALANCE - y PURCHASES - z PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 25/680  Now running combo : x BALANCE - y PURCHASES - z CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 26/680  Now running combo : x BALANCE - y PURCHASES - z PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 27/680  Now running combo : x BALANCE - y PURCHASES - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 28/680  Now running combo : x BALANCE - y PURCHASES - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 29/680  Now running combo : x BALANCE - y PURCHASES - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 30/680  Now running combo : x BALANCE - y ONEOFF_PURCHASES - z INSTALLMENTS_PURCHASES
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 31/680  Now running combo : x BALANCE - y ONEOFF_PURCHASES - z CASH_ADVANCE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 32/680  Now running combo : x BALANCE - y ONEOFF_PURCHASES - z PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 33/680  Now running combo : x BALANCE - y ONEOFF_PURCHASES - z ONEOFF_PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 34/680  Now running combo : x BALANCE - y ONEOFF_PURCHASES - z PURCHASES_INSTALLMENTS_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 35/680  Now running combo : x BALANCE - y ONEOFF_PURCHASES - z CASH_ADVANCE_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 36/680  Now running combo : x BALANCE - y ONEOFF_PURCHASES - z CASH_ADVANCE_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 37/680  Now running combo : x BALANCE - y ONEOFF_PURCHASES - z PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 38/680  Now running combo : x BALANCE - y ONEOFF_PURCHASES - z CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 39/680  Now running combo : x BALANCE - y ONEOFF_PURCHASES - z PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 40/680  Now running combo : x BALANCE - y ONEOFF_PURCHASES - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 41/680  Now running combo : x BALANCE - y ONEOFF_PURCHASES - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 42/680  Now running combo : x BALANCE - y ONEOFF_PURCHASES - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 43/680  Now running combo : x BALANCE - y INSTALLMENTS_PURCHASES - z CASH_ADVANCE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 44/680  Now running combo : x BALANCE - y INSTALLMENTS_PURCHASES - z PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 45/680  Now running combo : x BALANCE - y INSTALLMENTS_PURCHASES - z ONEOFF_PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 46/680  Now running combo : x BALANCE - y INSTALLMENTS_PURCHASES - z PURCHASES_INSTALLMENTS_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 47/680  Now running combo : x BALANCE - y INSTALLMENTS_PURCHASES - z CASH_ADVANCE_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 48/680  Now running combo : x BALANCE - y INSTALLMENTS_PURCHASES - z CASH_ADVANCE_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 49/680  Now running combo : x BALANCE - y INSTALLMENTS_PURCHASES - z PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 50/680  Now running combo : x BALANCE - y INSTALLMENTS_PURCHASES - z CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 51/680  Now running combo : x BALANCE - y INSTALLMENTS_PURCHASES - z PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 52/680  Now running combo : x BALANCE - y INSTALLMENTS_PURCHASES - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 53/680  Now running combo : x BALANCE - y INSTALLMENTS_PURCHASES - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 54/680  Now running combo : x BALANCE - y INSTALLMENTS_PURCHASES - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 55/680  Now running combo : x BALANCE - y CASH_ADVANCE - z PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 56/680  Now running combo : x BALANCE - y CASH_ADVANCE - z ONEOFF_PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 57/680  Now running combo : x BALANCE - y CASH_ADVANCE - z PURCHASES_INSTALLMENTS_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 58/680  Now running combo : x BALANCE - y CASH_ADVANCE - z CASH_ADVANCE_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 59/680  Now running combo : x BALANCE - y CASH_ADVANCE - z CASH_ADVANCE_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 60/680  Now running combo : x BALANCE - y CASH_ADVANCE - z PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 61/680  Now running combo : x BALANCE - y CASH_ADVANCE - z CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 62/680  Now running combo : x BALANCE - y CASH_ADVANCE - z PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 63/680  Now running combo : x BALANCE - y CASH_ADVANCE - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 64/680  Now running combo : x BALANCE - y CASH_ADVANCE - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 65/680  Now running combo : x BALANCE - y CASH_ADVANCE - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 66/680  Now running combo : x BALANCE - y PURCHASES_FREQUENCY - z ONEOFF_PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 67/680  Now running combo : x BALANCE - y PURCHASES_FREQUENCY - z PURCHASES_INSTALLMENTS_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 68/680  Now running combo : x BALANCE - y PURCHASES_FREQUENCY - z CASH_ADVANCE_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 69/680  Now running combo : x BALANCE - y PURCHASES_FREQUENCY - z CASH_ADVANCE_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 70/680  Now running combo : x BALANCE - y PURCHASES_FREQUENCY - z PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 71/680  Now running combo : x BALANCE - y PURCHASES_FREQUENCY - z CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 72/680  Now running combo : x BALANCE - y PURCHASES_FREQUENCY - z PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 73/680  Now running combo : x BALANCE - y PURCHASES_FREQUENCY - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 74/680  Now running combo : x BALANCE - y PURCHASES_FREQUENCY - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 75/680  Now running combo : x BALANCE - y PURCHASES_FREQUENCY - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 76/680  Now running combo : x BALANCE - y ONEOFF_PURCHASES_FREQUENCY - z PURCHASES_INSTALLMENTS_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 77/680  Now running combo : x BALANCE - y ONEOFF_PURCHASES_FREQUENCY - z CASH_ADVANCE_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 78/680  Now running combo : x BALANCE - y ONEOFF_PURCHASES_FREQUENCY - z CASH_ADVANCE_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 79/680  Now running combo : x BALANCE - y ONEOFF_PURCHASES_FREQUENCY - z PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 80/680  Now running combo : x BALANCE - y ONEOFF_PURCHASES_FREQUENCY - z CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 81/680  Now running combo : x BALANCE - y ONEOFF_PURCHASES_FREQUENCY - z PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 82/680  Now running combo : x BALANCE - y ONEOFF_PURCHASES_FREQUENCY - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 83/680  Now running combo : x BALANCE - y ONEOFF_PURCHASES_FREQUENCY - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 84/680  Now running combo : x BALANCE - y ONEOFF_PURCHASES_FREQUENCY - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 85/680  Now running combo : x BALANCE - y PURCHASES_INSTALLMENTS_FREQUENCY - z CASH_ADVANCE_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 86/680  Now running combo : x BALANCE - y PURCHASES_INSTALLMENTS_FREQUENCY - z CASH_ADVANCE_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 87/680  Now running combo : x BALANCE - y PURCHASES_INSTALLMENTS_FREQUENCY - z PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 88/680  Now running combo : x BALANCE - y PURCHASES_INSTALLMENTS_FREQUENCY - z CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 89/680  Now running combo : x BALANCE - y PURCHASES_INSTALLMENTS_FREQUENCY - z PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 90/680  Now running combo : x BALANCE - y PURCHASES_INSTALLMENTS_FREQUENCY - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 91/680  Now running combo : x BALANCE - y PURCHASES_INSTALLMENTS_FREQUENCY - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 92/680  Now running combo : x BALANCE - y PURCHASES_INSTALLMENTS_FREQUENCY - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 93/680  Now running combo : x BALANCE - y CASH_ADVANCE_FREQUENCY - z CASH_ADVANCE_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 94/680  Now running combo : x BALANCE - y CASH_ADVANCE_FREQUENCY - z PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 95/680  Now running combo : x BALANCE - y CASH_ADVANCE_FREQUENCY - z CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 96/680  Now running combo : x BALANCE - y CASH_ADVANCE_FREQUENCY - z PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 97/680  Now running combo : x BALANCE - y CASH_ADVANCE_FREQUENCY - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 98/680  Now running combo : x BALANCE - y CASH_ADVANCE_FREQUENCY - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 99/680  Now running combo : x BALANCE - y CASH_ADVANCE_FREQUENCY - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 100/680  Now running combo : x BALANCE - y CASH_ADVANCE_TRX - z PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 101/680  Now running combo : x BALANCE - y CASH_ADVANCE_TRX - z CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 102/680  Now running combo : x BALANCE - y CASH_ADVANCE_TRX - z PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 103/680  Now running combo : x BALANCE - y CASH_ADVANCE_TRX - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 104/680  Now running combo : x BALANCE - y CASH_ADVANCE_TRX - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 105/680  Now running combo : x BALANCE - y CASH_ADVANCE_TRX - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 106/680  Now running combo : x BALANCE - y PURCHASES_TRX - z CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 107/680  Now running combo : x BALANCE - y PURCHASES_TRX - z PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 108/680  Now running combo : x BALANCE - y PURCHASES_TRX - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 109/680  Now running combo : x BALANCE - y PURCHASES_TRX - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 110/680  Now running combo : x BALANCE - y PURCHASES_TRX - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 111/680  Now running combo : x BALANCE - y CREDIT_LIMIT - z PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 112/680  Now running combo : x BALANCE - y CREDIT_LIMIT - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 113/680  Now running combo : x BALANCE - y CREDIT_LIMIT - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 114/680  Now running combo : x BALANCE - y CREDIT_LIMIT - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 115/680  Now running combo : x BALANCE - y PAYMENTS - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 116/680  Now running combo : x BALANCE - y PAYMENTS - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 117/680  Now running combo : x BALANCE - y PAYMENTS - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 118/680  Now running combo : x BALANCE - y MINIMUM_PAYMENTS - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 119/680  Now running combo : x BALANCE - y MINIMUM_PAYMENTS - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 120/680  Now running combo : x BALANCE - y PRC_FULL_PAYMENT - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 121/680  Now running combo : x BALANCE_FREQUENCY - y PURCHASES - z ONEOFF_PURCHASES
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 122/680  Now running combo : x BALANCE_FREQUENCY - y PURCHASES - z INSTALLMENTS_PURCHASES
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 123/680  Now running combo : x BALANCE_FREQUENCY - y PURCHASES - z CASH_ADVANCE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 124/680  Now running combo : x BALANCE_FREQUENCY - y PURCHASES - z PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 125/680  Now running combo : x BALANCE_FREQUENCY - y PURCHASES - z ONEOFF_PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 126/680  Now running combo : x BALANCE_FREQUENCY - y PURCHASES - z PURCHASES_INSTALLMENTS_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 127/680  Now running combo : x BALANCE_FREQUENCY - y PURCHASES - z CASH_ADVANCE_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 128/680  Now running combo : x BALANCE_FREQUENCY - y PURCHASES - z CASH_ADVANCE_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 129/680  Now running combo : x BALANCE_FREQUENCY - y PURCHASES - z PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 130/680  Now running combo : x BALANCE_FREQUENCY - y PURCHASES - z CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 131/680  Now running combo : x BALANCE_FREQUENCY - y PURCHASES - z PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 132/680  Now running combo : x BALANCE_FREQUENCY - y PURCHASES - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 133/680  Now running combo : x BALANCE_FREQUENCY - y PURCHASES - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 134/680  Now running combo : x BALANCE_FREQUENCY - y PURCHASES - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 135/680  Now running combo : x BALANCE_FREQUENCY - y ONEOFF_PURCHASES - z INSTALLMENTS_PURCHASES
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 136/680  Now running combo : x BALANCE_FREQUENCY - y ONEOFF_PURCHASES - z CASH_ADVANCE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 137/680  Now running combo : x BALANCE_FREQUENCY - y ONEOFF_PURCHASES - z PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 138/680  Now running combo : x BALANCE_FREQUENCY - y ONEOFF_PURCHASES - z ONEOFF_PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 139/680  Now running combo : x BALANCE_FREQUENCY - y ONEOFF_PURCHASES - z PURCHASES_INSTALLMENTS_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 140/680  Now running combo : x BALANCE_FREQUENCY - y ONEOFF_PURCHASES - z CASH_ADVANCE_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 141/680  Now running combo : x BALANCE_FREQUENCY - y ONEOFF_PURCHASES - z CASH_ADVANCE_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 142/680  Now running combo : x BALANCE_FREQUENCY - y ONEOFF_PURCHASES - z PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 143/680  Now running combo : x BALANCE_FREQUENCY - y ONEOFF_PURCHASES - z CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 144/680  Now running combo : x BALANCE_FREQUENCY - y ONEOFF_PURCHASES - z PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 145/680  Now running combo : x BALANCE_FREQUENCY - y ONEOFF_PURCHASES - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 146/680  Now running combo : x BALANCE_FREQUENCY - y ONEOFF_PURCHASES - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 147/680  Now running combo : x BALANCE_FREQUENCY - y ONEOFF_PURCHASES - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 148/680  Now running combo : x BALANCE_FREQUENCY - y INSTALLMENTS_PURCHASES - z CASH_ADVANCE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 149/680  Now running combo : x BALANCE_FREQUENCY - y INSTALLMENTS_PURCHASES - z PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 150/680  Now running combo : x BALANCE_FREQUENCY - y INSTALLMENTS_PURCHASES - z ONEOFF_PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 151/680  Now running combo : x BALANCE_FREQUENCY - y INSTALLMENTS_PURCHASES - z PURCHASES_INSTALLMENTS_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 152/680  Now running combo : x BALANCE_FREQUENCY - y INSTALLMENTS_PURCHASES - z CASH_ADVANCE_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 153/680  Now running combo : x BALANCE_FREQUENCY - y INSTALLMENTS_PURCHASES - z CASH_ADVANCE_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 154/680  Now running combo : x BALANCE_FREQUENCY - y INSTALLMENTS_PURCHASES - z PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 155/680  Now running combo : x BALANCE_FREQUENCY - y INSTALLMENTS_PURCHASES - z CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 156/680  Now running combo : x BALANCE_FREQUENCY - y INSTALLMENTS_PURCHASES - z PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 157/680  Now running combo : x BALANCE_FREQUENCY - y INSTALLMENTS_PURCHASES - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 158/680  Now running combo : x BALANCE_FREQUENCY - y INSTALLMENTS_PURCHASES - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 159/680  Now running combo : x BALANCE_FREQUENCY - y INSTALLMENTS_PURCHASES - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 160/680  Now running combo : x BALANCE_FREQUENCY - y CASH_ADVANCE - z PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 161/680  Now running combo : x BALANCE_FREQUENCY - y CASH_ADVANCE - z ONEOFF_PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 162/680  Now running combo : x BALANCE_FREQUENCY - y CASH_ADVANCE - z PURCHASES_INSTALLMENTS_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 163/680  Now running combo : x BALANCE_FREQUENCY - y CASH_ADVANCE - z CASH_ADVANCE_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 164/680  Now running combo : x BALANCE_FREQUENCY - y CASH_ADVANCE - z CASH_ADVANCE_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 165/680  Now running combo : x BALANCE_FREQUENCY - y CASH_ADVANCE - z PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 166/680  Now running combo : x BALANCE_FREQUENCY - y CASH_ADVANCE - z CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 167/680  Now running combo : x BALANCE_FREQUENCY - y CASH_ADVANCE - z PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 168/680  Now running combo : x BALANCE_FREQUENCY - y CASH_ADVANCE - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 169/680  Now running combo : x BALANCE_FREQUENCY - y CASH_ADVANCE - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ...
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 625/680  Now running combo : x CASH_ADVANCE_FREQUENCY - y CASH_ADVANCE_TRX - z PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 626/680  Now running combo : x CASH_ADVANCE_FREQUENCY - y CASH_ADVANCE_TRX - z CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 627/680  Now running combo : x CASH_ADVANCE_FREQUENCY - y CASH_ADVANCE_TRX - z PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 628/680  Now running combo : x CASH_ADVANCE_FREQUENCY - y CASH_ADVANCE_TRX - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 629/680  Now running combo : x CASH_ADVANCE_FREQUENCY - y CASH_ADVANCE_TRX - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 630/680  Now running combo : x CASH_ADVANCE_FREQUENCY - y CASH_ADVANCE_TRX - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 631/680  Now running combo : x CASH_ADVANCE_FREQUENCY - y PURCHASES_TRX - z CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 632/680  Now running combo : x CASH_ADVANCE_FREQUENCY - y PURCHASES_TRX - z PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 633/680  Now running combo : x CASH_ADVANCE_FREQUENCY - y PURCHASES_TRX - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 634/680  Now running combo : x CASH_ADVANCE_FREQUENCY - y PURCHASES_TRX - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 635/680  Now running combo : x CASH_ADVANCE_FREQUENCY - y PURCHASES_TRX - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 636/680  Now running combo : x CASH_ADVANCE_FREQUENCY - y CREDIT_LIMIT - z PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 637/680  Now running combo : x CASH_ADVANCE_FREQUENCY - y CREDIT_LIMIT - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 638/680  Now running combo : x CASH_ADVANCE_FREQUENCY - y CREDIT_LIMIT - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 639/680  Now running combo : x CASH_ADVANCE_FREQUENCY - y CREDIT_LIMIT - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 640/680  Now running combo : x CASH_ADVANCE_FREQUENCY - y PAYMENTS - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 641/680  Now running combo : x CASH_ADVANCE_FREQUENCY - y PAYMENTS - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 642/680  Now running combo : x CASH_ADVANCE_FREQUENCY - y PAYMENTS - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 643/680  Now running combo : x CASH_ADVANCE_FREQUENCY - y MINIMUM_PAYMENTS - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 644/680  Now running combo : x CASH_ADVANCE_FREQUENCY - y MINIMUM_PAYMENTS - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 645/680  Now running combo : x CASH_ADVANCE_FREQUENCY - y PRC_FULL_PAYMENT - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 646/680  Now running combo : x CASH_ADVANCE_TRX - y PURCHASES_TRX - z CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 647/680  Now running combo : x CASH_ADVANCE_TRX - y PURCHASES_TRX - z PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 648/680  Now running combo : x CASH_ADVANCE_TRX - y PURCHASES_TRX - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 649/680  Now running combo : x CASH_ADVANCE_TRX - y PURCHASES_TRX - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 650/680  Now running combo : x CASH_ADVANCE_TRX - y PURCHASES_TRX - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 651/680  Now running combo : x CASH_ADVANCE_TRX - y CREDIT_LIMIT - z PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 652/680  Now running combo : x CASH_ADVANCE_TRX - y CREDIT_LIMIT - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 653/680  Now running combo : x CASH_ADVANCE_TRX - y CREDIT_LIMIT - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 654/680  Now running combo : x CASH_ADVANCE_TRX - y CREDIT_LIMIT - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 655/680  Now running combo : x CASH_ADVANCE_TRX - y PAYMENTS - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 656/680  Now running combo : x CASH_ADVANCE_TRX - y PAYMENTS - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 657/680  Now running combo : x CASH_ADVANCE_TRX - y PAYMENTS - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 658/680  Now running combo : x CASH_ADVANCE_TRX - y MINIMUM_PAYMENTS - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 659/680  Now running combo : x CASH_ADVANCE_TRX - y MINIMUM_PAYMENTS - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 660/680  Now running combo : x CASH_ADVANCE_TRX - y PRC_FULL_PAYMENT - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 661/680  Now running combo : x PURCHASES_TRX - y CREDIT_LIMIT - z PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 662/680  Now running combo : x PURCHASES_TRX - y CREDIT_LIMIT - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 663/680  Now running combo : x PURCHASES_TRX - y CREDIT_LIMIT - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 664/680  Now running combo : x PURCHASES_TRX - y CREDIT_LIMIT - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 665/680  Now running combo : x PURCHASES_TRX - y PAYMENTS - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 666/680  Now running combo : x PURCHASES_TRX - y PAYMENTS - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 667/680  Now running combo : x PURCHASES_TRX - y PAYMENTS - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 668/680  Now running combo : x PURCHASES_TRX - y MINIMUM_PAYMENTS - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 669/680  Now running combo : x PURCHASES_TRX - y MINIMUM_PAYMENTS - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 670/680  Now running combo : x PURCHASES_TRX - y PRC_FULL_PAYMENT - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 671/680  Now running combo : x CREDIT_LIMIT - y PAYMENTS - z MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 672/680  Now running combo : x CREDIT_LIMIT - y PAYMENTS - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 673/680  Now running combo : x CREDIT_LIMIT - y PAYMENTS - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 674/680  Now running combo : x CREDIT_LIMIT - y MINIMUM_PAYMENTS - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 675/680  Now running combo : x CREDIT_LIMIT - y MINIMUM_PAYMENTS - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 676/680  Now running combo : x CREDIT_LIMIT - y PRC_FULL_PAYMENT - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 677/680  Now running combo : x PAYMENTS - y MINIMUM_PAYMENTS - z PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 678/680  Now running combo : x PAYMENTS - y MINIMUM_PAYMENTS - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 679/680  Now running combo : x PAYMENTS - y PRC_FULL_PAYMENT - z TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 680/680  Now running combo : x MINIMUM_PAYMENTS - y PRC_FULL_PAYMENT - z TENURE
# ------------------------------------------------------------------------------------------------
#
# All plots with legends are saved.

# %%
import matplotlib.pyplot as plt
from itertools import combinations
import numpy as np
import os

columns = imputed_dataset.columns

column_combinations = combinations(columns, 2)

num_combinations = len(list(column_combinations))
run = 0

column_combinations = combinations(columns, 2)

for combo in column_combinations:
    run = 1 + run
    x, y = combo
    print('')
    print('------------------------------------------------------------------------------------------------')
    print(f'Run {run}/{num_combinations}  Now running combo : x {x} - y {y}')
    print('------------------------------------------------------------------------------------------------')
    print('') 

    
    fig, ax = plt.subplots(figsize=(12, 8))

    scatter = ax.scatter(imputed_dataset[x], imputed_dataset[y], c=kmeans.labels_, cmap='viridis', s=20)

    ax.set_xlabel(x)
    ax.set_ylabel(y)

    unique_labels = np.unique(kmeans.labels_)
    legend_labels = {}

    for label in unique_labels:
        value = f'Cluster {label}'
        legend_labels[label] = value

    legend_handles = []

    for label, legend in legend_labels.items():
        color = plt.cm.viridis(label / max(kmeans.labels_))
        handle = plt.Line2D([0], [0], marker='o', color='w', label=legend, markerfacecolor=color, markersize=10)
        legend_handles.append(handle)
    
    ax.legend(handles=legend_handles, title="Clusters")

    filename = f"{x}_{y}.png"
    if not os.path.exists('/tmp/data/2d-data/'):
        os.makedirs('/tmp/data/2d-data/')
    plt.savefig(f'/tmp/data/2d-data/{filename}')
    plt.close()

print("All 2D plots with legends are saved.")
# Out:
# ------------------------------------------------------------------------------------------------
# Run 1/136  Now running combo : x BALANCE - y BALANCE_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 2/136  Now running combo : x BALANCE - y PURCHASES
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 3/136  Now running combo : x BALANCE - y ONEOFF_PURCHASES
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 4/136  Now running combo : x BALANCE - y INSTALLMENTS_PURCHASES
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 5/136  Now running combo : x BALANCE - y CASH_ADVANCE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 6/136  Now running combo : x BALANCE - y PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 7/136  Now running combo : x BALANCE - y ONEOFF_PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 8/136  Now running combo : x BALANCE - y PURCHASES_INSTALLMENTS_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 9/136  Now running combo : x BALANCE - y CASH_ADVANCE_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 10/136  Now running combo : x BALANCE - y CASH_ADVANCE_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 11/136  Now running combo : x BALANCE - y PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 12/136  Now running combo : x BALANCE - y CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 13/136  Now running combo : x BALANCE - y PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 14/136  Now running combo : x BALANCE - y MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 15/136  Now running combo : x BALANCE - y PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 16/136  Now running combo : x BALANCE - y TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 17/136  Now running combo : x BALANCE_FREQUENCY - y PURCHASES
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 18/136  Now running combo : x BALANCE_FREQUENCY - y ONEOFF_PURCHASES
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 19/136  Now running combo : x BALANCE_FREQUENCY - y INSTALLMENTS_PURCHASES
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 20/136  Now running combo : x BALANCE_FREQUENCY - y CASH_ADVANCE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 21/136  Now running combo : x BALANCE_FREQUENCY - y PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 22/136  Now running combo : x BALANCE_FREQUENCY - y ONEOFF_PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 23/136  Now running combo : x BALANCE_FREQUENCY - y PURCHASES_INSTALLMENTS_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 24/136  Now running combo : x BALANCE_FREQUENCY - y CASH_ADVANCE_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 25/136  Now running combo : x BALANCE_FREQUENCY - y CASH_ADVANCE_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 26/136  Now running combo : x BALANCE_FREQUENCY - y PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 27/136  Now running combo : x BALANCE_FREQUENCY - y CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 28/136  Now running combo : x BALANCE_FREQUENCY - y PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 29/136  Now running combo : x BALANCE_FREQUENCY - y MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 30/136  Now running combo : x BALANCE_FREQUENCY - y PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 31/136  Now running combo : x BALANCE_FREQUENCY - y TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 32/136  Now running combo : x PURCHASES - y ONEOFF_PURCHASES
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 33/136  Now running combo : x PURCHASES - y INSTALLMENTS_PURCHASES
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 34/136  Now running combo : x PURCHASES - y CASH_ADVANCE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 35/136  Now running combo : x PURCHASES - y PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 36/136  Now running combo : x PURCHASES - y ONEOFF_PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 37/136  Now running combo : x PURCHASES - y PURCHASES_INSTALLMENTS_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 38/136  Now running combo : x PURCHASES - y CASH_ADVANCE_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 39/136  Now running combo : x PURCHASES - y CASH_ADVANCE_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 40/136  Now running combo : x PURCHASES - y PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 41/136  Now running combo : x PURCHASES - y CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 42/136  Now running combo : x PURCHASES - y PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 43/136  Now running combo : x PURCHASES - y MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 44/136  Now running combo : x PURCHASES - y PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 45/136  Now running combo : x PURCHASES - y TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 46/136  Now running combo : x ONEOFF_PURCHASES - y INSTALLMENTS_PURCHASES
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 47/136  Now running combo : x ONEOFF_PURCHASES - y CASH_ADVANCE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 48/136  Now running combo : x ONEOFF_PURCHASES - y PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 49/136  Now running combo : x ONEOFF_PURCHASES - y ONEOFF_PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 50/136  Now running combo : x ONEOFF_PURCHASES - y PURCHASES_INSTALLMENTS_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 51/136  Now running combo : x ONEOFF_PURCHASES - y CASH_ADVANCE_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 52/136  Now running combo : x ONEOFF_PURCHASES - y CASH_ADVANCE_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 53/136  Now running combo : x ONEOFF_PURCHASES - y PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 54/136  Now running combo : x ONEOFF_PURCHASES - y CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 55/136  Now running combo : x ONEOFF_PURCHASES - y PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 56/136  Now running combo : x ONEOFF_PURCHASES - y MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 57/136  Now running combo : x ONEOFF_PURCHASES - y PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 58/136  Now running combo : x ONEOFF_PURCHASES - y TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 59/136  Now running combo : x INSTALLMENTS_PURCHASES - y CASH_ADVANCE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 60/136  Now running combo : x INSTALLMENTS_PURCHASES - y PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 61/136  Now running combo : x INSTALLMENTS_PURCHASES - y ONEOFF_PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 62/136  Now running combo : x INSTALLMENTS_PURCHASES - y PURCHASES_INSTALLMENTS_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 63/136  Now running combo : x INSTALLMENTS_PURCHASES - y CASH_ADVANCE_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 64/136  Now running combo : x INSTALLMENTS_PURCHASES - y CASH_ADVANCE_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 65/136  Now running combo : x INSTALLMENTS_PURCHASES - y PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 66/136  Now running combo : x INSTALLMENTS_PURCHASES - y CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 67/136  Now running combo : x INSTALLMENTS_PURCHASES - y PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 68/136  Now running combo : x INSTALLMENTS_PURCHASES - y MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 69/136  Now running combo : x INSTALLMENTS_PURCHASES - y PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 70/136  Now running combo : x INSTALLMENTS_PURCHASES - y TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 71/136  Now running combo : x CASH_ADVANCE - y PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 72/136  Now running combo : x CASH_ADVANCE - y ONEOFF_PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 73/136  Now running combo : x CASH_ADVANCE - y PURCHASES_INSTALLMENTS_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 74/136  Now running combo : x CASH_ADVANCE - y CASH_ADVANCE_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 75/136  Now running combo : x CASH_ADVANCE - y CASH_ADVANCE_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 76/136  Now running combo : x CASH_ADVANCE - y PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 77/136  Now running combo : x CASH_ADVANCE - y CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 78/136  Now running combo : x CASH_ADVANCE - y PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 79/136  Now running combo : x CASH_ADVANCE - y MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 80/136  Now running combo : x CASH_ADVANCE - y PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 81/136  Now running combo : x CASH_ADVANCE - y TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 82/136  Now running combo : x PURCHASES_FREQUENCY - y ONEOFF_PURCHASES_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 83/136  Now running combo : x PURCHASES_FREQUENCY - y PURCHASES_INSTALLMENTS_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 84/136  Now running combo : x PURCHASES_FREQUENCY - y CASH_ADVANCE_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 85/136  Now running combo : x PURCHASES_FREQUENCY - y CASH_ADVANCE_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 86/136  Now running combo : x PURCHASES_FREQUENCY - y PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 87/136  Now running combo : x PURCHASES_FREQUENCY - y CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 88/136  Now running combo : x PURCHASES_FREQUENCY - y PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 89/136  Now running combo : x PURCHASES_FREQUENCY - y MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 90/136  Now running combo : x PURCHASES_FREQUENCY - y PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 91/136  Now running combo : x PURCHASES_FREQUENCY - y TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 92/136  Now running combo : x ONEOFF_PURCHASES_FREQUENCY - y PURCHASES_INSTALLMENTS_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 93/136  Now running combo : x ONEOFF_PURCHASES_FREQUENCY - y CASH_ADVANCE_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 94/136  Now running combo : x ONEOFF_PURCHASES_FREQUENCY - y CASH_ADVANCE_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 95/136  Now running combo : x ONEOFF_PURCHASES_FREQUENCY - y PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 96/136  Now running combo : x ONEOFF_PURCHASES_FREQUENCY - y CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 97/136  Now running combo : x ONEOFF_PURCHASES_FREQUENCY - y PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 98/136  Now running combo : x ONEOFF_PURCHASES_FREQUENCY - y MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 99/136  Now running combo : x ONEOFF_PURCHASES_FREQUENCY - y PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 100/136  Now running combo : x ONEOFF_PURCHASES_FREQUENCY - y TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 101/136  Now running combo : x PURCHASES_INSTALLMENTS_FREQUENCY - y CASH_ADVANCE_FREQUENCY
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 102/136  Now running combo : x PURCHASES_INSTALLMENTS_FREQUENCY - y CASH_ADVANCE_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 103/136  Now running combo : x PURCHASES_INSTALLMENTS_FREQUENCY - y PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 104/136  Now running combo : x PURCHASES_INSTALLMENTS_FREQUENCY - y CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 105/136  Now running combo : x PURCHASES_INSTALLMENTS_FREQUENCY - y PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 106/136  Now running combo : x PURCHASES_INSTALLMENTS_FREQUENCY - y MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 107/136  Now running combo : x PURCHASES_INSTALLMENTS_FREQUENCY - y PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 108/136  Now running combo : x PURCHASES_INSTALLMENTS_FREQUENCY - y TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 109/136  Now running combo : x CASH_ADVANCE_FREQUENCY - y CASH_ADVANCE_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 110/136  Now running combo : x CASH_ADVANCE_FREQUENCY - y PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 111/136  Now running combo : x CASH_ADVANCE_FREQUENCY - y CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 112/136  Now running combo : x CASH_ADVANCE_FREQUENCY - y PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 113/136  Now running combo : x CASH_ADVANCE_FREQUENCY - y MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 114/136  Now running combo : x CASH_ADVANCE_FREQUENCY - y PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 115/136  Now running combo : x CASH_ADVANCE_FREQUENCY - y TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 116/136  Now running combo : x CASH_ADVANCE_TRX - y PURCHASES_TRX
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 117/136  Now running combo : x CASH_ADVANCE_TRX - y CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 118/136  Now running combo : x CASH_ADVANCE_TRX - y PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 119/136  Now running combo : x CASH_ADVANCE_TRX - y MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 120/136  Now running combo : x CASH_ADVANCE_TRX - y PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 121/136  Now running combo : x CASH_ADVANCE_TRX - y TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 122/136  Now running combo : x PURCHASES_TRX - y CREDIT_LIMIT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 123/136  Now running combo : x PURCHASES_TRX - y PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 124/136  Now running combo : x PURCHASES_TRX - y MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 125/136  Now running combo : x PURCHASES_TRX - y PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 126/136  Now running combo : x PURCHASES_TRX - y TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 127/136  Now running combo : x CREDIT_LIMIT - y PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 128/136  Now running combo : x CREDIT_LIMIT - y MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 129/136  Now running combo : x CREDIT_LIMIT - y PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 130/136  Now running combo : x CREDIT_LIMIT - y TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 131/136  Now running combo : x PAYMENTS - y MINIMUM_PAYMENTS
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 132/136  Now running combo : x PAYMENTS - y PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 133/136  Now running combo : x PAYMENTS - y TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 134/136  Now running combo : x MINIMUM_PAYMENTS - y PRC_FULL_PAYMENT
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 135/136  Now running combo : x MINIMUM_PAYMENTS - y TENURE
# ------------------------------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------------------------------
# Run 136/136  Now running combo : x PRC_FULL_PAYMENT - y TENURE
# ------------------------------------------------------------------------------------------------
#
# All 2D plots with legends are saved.
